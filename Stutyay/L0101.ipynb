# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
census_1991 = pd.read_csv(r"C:\Users\stuti\OneDrive\Desktop\temp_1\1991_Census.csv")
census_2001 = pd.read_csv(r"C:\Users\stuti\OneDrive\Desktop\temp_1\2001_Census.csv")
census_2011 = pd.read_csv(r"C:\Users\stuti\OneDrive\Desktop\temp_1\2011_Census.csv")
census_2001
# Out:
#     S.No.                                  State  Total_Population  \
# 0       1            State - JAMMU & KASHMIR  01          10143700
# 1       2           State - HIMACHAL PRADESH  02           6077900
# 2       3                     State - PUNJAB  03          24358999
# 3       4                 State - CHANDIGARH  04            900635
# 4       5                State - UTTARANCHAL  05           8489349
# 5       6                    State - HARYANA  06          21144564
# 6       7                      State - DELHI  07          13850507
# 7       8                  State - RAJASTHAN  08          56507188
# 8       9              State - UTTAR PRADESH  09         166197921
# 9      10                      State - BIHAR  10          82998509
# 10     11                     State - SIKKIM  11            540851
# 11     12          State - ARUNACHAL PRADESH  12           1097968
# 12     13                   State - NAGALAND  13           1990036
# ...

# %%
columns_needed = ["LiteracyRate" , "GrowthRate"]
census_1991 = census_1991[columns_needed]
census_2001 = census_2001[columns_needed]
census_2011 = census_2011[columns_needed]

# %%
#Creating subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
# Plot 1991 data
sns.lineplot(ax=axes[0], data=census_1991, y="X..1981 to 1991", x="Literacy_rates")
axes[0].set_title("1991 Census Data")

# Plot 2001 data
sns.lineplot(ax=axes[1], data=census_2001, y="X..1991 to 2001", x="Literacy_Rates")
axes[1].set_title("2001 Census Data")
plt.setp(axes[1].get_xticklabels(), rotation=90, ha="right")

# Plot 2011 data
sns.lineplot(ax=axes[2], data=census_2011, y="X..2001 to 2011", x="Literacy_rates")
axes[2].set_title("2011 Census Data")

# Show the plots
plt.tight_layout()
plt.show()

# %%
#Creating subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
# Plot 1991 data
sns.scatterplot(ax=axes[0], data=census_1991, y="X..1981 to 1991", x="Literacy_rates")
axes[0].set_title("1991 Census Data")

# Plot 2001 data
sns.scatterplot(ax=axes[1], data=census_2001, y="X..1991 to 2001", x="Literacy_Rates")
axes[1].set_title("2001 Census Data")
plt.setp(axes[1].get_xticklabels(), rotation=90, ha="right")

# Plot 2011 data
sns.scatterplot(ax=axes[2], data=census_2011, y="X..2001 to 2011", x="Literacy_rates")
axes[2].set_title("2011 Census Data")

# Show the plots
plt.tight_layout()
plt.show()

# %%
#Creating subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
# Plot 1991 data
sns.barplot(ax=axes[0], data=census_1991, y="X..1981 to 1991", x="Literacy_rates")
axes[0].set_title("1991 Census Data")
plt.setp(axes[0].get_xticklabels(), rotation=90, ha="right")

# Plot 2001 data
sns.barplot(ax=axes[1], data=census_2001, y="X..1991 to 2001", x="Literacy_Rates")
axes[1].set_title("2001 Census Data")
plt.setp(axes[1].get_xticklabels(), rotation=90, ha="right")

# Plot 2011 data
sns.barplot(ax=axes[2], data=census_2011, y="X..2001 to 2011", x="Literacy_rates")
axes[2].set_title("2011 Census Data")
plt.setp(axes[2].get_xticklabels(), rotation=90, ha="right")

# Show the plots
plt.tight_layout()
plt.show()
