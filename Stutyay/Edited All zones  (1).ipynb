# %% [markdown]
# # Analysis of Literacy Rate by Gender with Respect to Rural and Urban Divide by Zonal Division
#
# ## Aim
# The objective of this analysis is to visualize the literacy rates of males and females with the urban and rural divide among the six different zones (North, South, East, West, Central, and Northeast). The information regarding which state lies in which region can be found on the official government website: [Zones](https://www.mha.gov.in/sites/default/files/ZCS-CitiCharter-130710_1.pdf).
#
# ## Formulas
# The formulas used for calculating the literacy rates of males and females with respect to the urban and rural divide are as follows:
# $$
# \text{Rural Literacy Rate} = \left( \frac{\text{Total Rural Literates (age 7+)}}{\text{Total Rural Population (age 7+)}} \right) \times 100
# $$
#
# $$
# \text{Rural Male Literacy Rate} = \left( \frac{\text{Rural Male Literates (age 7+)}}{\text{Total Rural Male Population (age 7+)}} \right) \times 100
# $$
#
# $$
# \text{Rural Female Literacy Rate} = \left( \frac{\text{Rural Female Literates (age 7+)}}{\text{Total Rural Female Population (age 7+)}} \right) \times 100
# $$
#
# $$
# \text{Urban Literacy Rate} = \left( \frac{\text{Total Urban Literates (age 7+)}}{\text{Total Urban Population (age 7+)}} \right) \times 100
# $$
#
# $$
# \text{Urban Male Literacy Rate} = \left( \frac{\text{Urban Male Literates (age 7+)}}{\text{Total Urban Male Population (age 7+)}} \right) \times 100
# $$
#
# $$
# \text{Urban Female Literacy Rate} = \left( \frac{\text{Urban Female Literates (age 7+)}}{\text{Total Urban Female Population (age 7+)}} \right) \times 100
# $$
#
# $$
# \text{Gender Gap Rural} = \text{Rural Male Literacy Rate} - \text{Rural Female Literacy Rate}
# $$
#
# $$
# \text{Gender Gap Urban} = \text{Urban Male Literacy Rate} - \text{Urban Female Literacy Rate}
# $$
#
#
#
# ## Source for Data
# The data for this analysis is sourced from the Census of India 2011. The original data can be downloaded from the census website: [Census Data](https://censusindia.gov.in/census.website/data/census-tables#) and [Census 2011](https://github.com/Shubham18024/Census_Analysis/blob/c4c6fa2c0852a64dc26ded80ce3ce15e9a133620/CSV%20files%20for%201991%2C2001%2C2011/DDW-0000C-08.xlsx).
#
# ## Refined Data
# The data has been refined to study the literacy rates of males and females with the rural and urban divide among six different zones and compare it to the national average literacy rate. The refined data can be found on GitHub:
#
# - [Census 2011 Gender and literacy rate wrt urban and rural divide](https://github.com/Shubham18024/Census_Analysis/blob/1b636740aaac6a7c8aad63aaac3fec7c2b2a251e/CSV%20files%20for%201991%2C2001%2C2011/Census%202011%20Gender%20and%20literacy%20rate%20wrt%20urban%20and%20rural%20divide.xlsx)
# - [Central Zone](https://github.com/Shubham18024/Census_Analysis/blob/1b636740aaac6a7c8aad63aaac3fec7c2b2a251e/CSV%20files%20for%201991%2C2001%2C2011/Central%20Zone.xlsx)
# - [Eastern Zone](https://github.com/Shubham18024/Census_Analysis/blob/1b636740aaac6a7c8aad63aaac3fec7c2b2a251e/CSV%20files%20for%201991%2C2001%2C2011/Eastern%20Zone.xlsx)
# - [Northeastern Zone](https://github.com/Shubham18024/Census_Analysis/blob/1b636740aaac6a7c8aad63aaac3fec7c2b2a251e/CSV%20files%20for%201991%2C2001%2C2011/Northeastern%20Zone.xlsx)
# - [Northern Zone](https://github.com/Shubham18024/Census_Analysis/blob/1b636740aaac6a7c8aad63aaac3fec7c2b2a251e/CSV%20files%20for%201991%2C2001%2C2011/Northern%20zone.xlsx)
# - [Southern Zone](https://github.com/Shubham18024/Census_Analysis/blob/1b636740aaac6a7c8aad63aaac3fec7c2b2a251e/CSV%20files%20for%201991%2C2001%2C2011/Southern%20Zone.xlsx)
# - [Western Zone](https://github.com/Shubham18024/Census_Analysis/blob/1b636740aaac6a7c8aad63aaac3fec7c2b2a251e/CSV%20files%20for%201991%2C2001%2C2011/Western%20Zone.xlsx)
#
# ## Visualization
# Below is the code written to generate a grouped bar chart of the literacy rates of males and females with the rural and urban divide among six different zones, along with a comparison to the national average literacy rate.

# %%
# Importing the Necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Loading the CSV file 
df = pd.read_csv(r"C:\Users\stuti\OneDrive\Desktop\temp_1\All zones combined.csv")
df
# Out:
#            Zone  Rural_Total  Rural_Total Males  Rural_Total Females  \
# 0       Nothern     86073733           44630000             41443733
# 1       Central    197237566          101991885             95245681
# 2       Eastern    180452396           92759832             87692564
# 3       Western     84442111           43109387             41332724
# 4     Southern     132477815           65997028             66480787
# 5  Northeastern     31519362           16089267             15430095
#
#    Rural_Total_Literate  Rural_Literate Males  Rural_Literate Females  \
# 0              57164132              34720144                22443988
# 1             129189672              77847853                51341819
# 2             118046924              68927310                49119614
# 3              63477105              36175840                27301265
# 4              92332638              51237796                41094842
# ...

# %%
#Selecting the relevant columns from the df
rural_data = df[["Zone", "Rural_Male_LiteracyRate(age 7+)", "Rural_Female_LiteracyRate(age 7 +)"]]

# Set up the plot
fig, ax = plt.subplots(figsize=(18, 12))

# Set the width of each bar and the positions of the bar 
bar_width = 0.35
r1 = range(len(rural_data))
r2 = [x + bar_width for x in r1]

# Create the bars
male_bars = ax.bar(r1, rural_data["Rural_Male_LiteracyRate(age 7+)"], color="blue", width=bar_width, label="Males")
female_bars = ax.bar(r2, rural_data["Rural_Female_LiteracyRate(age 7 +)"], color="orange", width=bar_width, label="Females")

# Add horizontal line for national average
national_avg = 67.76
national_avg_line = ax.axhline(y=national_avg, color="r", linestyle="--", linewidth=2, label=f'Rural Avg Literacy: {national_avg}%')

# Customize the plot
ax.set_ylabel("Literacy Rates (%)", fontsize=25, fontweight='bold', fontname="Times New Roman")
ax.set_xticks([r + bar_width/2 for r in range(len(rural_data))])
ax.set_xticklabels(rural_data["Zone"], rotation=40, ha='right', fontsize=14, fontweight='bold', fontname="Times New Roman")
ax.tick_params(axis='y', labelsize=16)
ax.tick_params(axis='x', labelsize=18)

# Adjust y-axis scale
ax.set_ylim(0, 100)
ax.set_yticks(np.arange(0, 101, 20))

# Add percentage values on top of each bar
def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.1f}%',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=14)

autolabel(male_bars)
autolabel(female_bars)


# Adjust legend to avoid overlap and place it outside the plot
ax.legend([male_bars, female_bars, national_avg_line], 
          ['Males', 'Females', f'Rural Avg literacy: {national_avg}%'], 
          loc="upper left", bbox_to_anchor=(1,1), fontsize=14)

# Adjust layout
plt.tight_layout()
plt.subplots_adjust(right=0.85)

# Save the Rural Literacy Rates image
plt.savefig('Rural_Literacy_Rates.png', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# %%
# Selecting the relevant columns from the df
urban_data = df[["Zone", "Urban_Male_LiteracyRate(age 7+)", "Urban_Female_LiteracyRate(age 7+)"]]

# Set up the plot
fig, ax = plt.subplots(figsize=(18, 12))

# Set the width of each bar and the positions of the bar 
bar_width = 0.35
r1 = range(len(urban_data))
r2 = [x + bar_width for x in r1]

# Create the bars
male_bars = ax.bar(r1, urban_data["Urban_Male_LiteracyRate(age 7+)"], color="blue", width=bar_width, label="Males")
female_bars = ax.bar(r2, urban_data["Urban_Female_LiteracyRate(age 7+)"], color="orange", width=bar_width, label="Females")

# Add horizontal line for national average
national_avg = 84.10
national_avg_line = ax.axhline(y=national_avg, color="r", linestyle="--", linewidth=2, label=f'Urban Avg Literacy: {national_avg}%')

# Customize the plot
ax.set_ylabel("Literacy Rates (%)", fontsize=25, fontweight='bold', fontname="Times New Roman")
ax.set_title("Urban Literacy Rates by Gender", fontsize=38, fontweight='bold', fontname="Times New Roman", pad=20)
ax.set_xticks([r + bar_width/2 for r in range(len(rural_data))])
ax.set_xticklabels(rural_data["Zone"], rotation=40, ha='right', fontsize=14, fontweight='bold', fontname="Times New Roman")
ax.tick_params(axis='y', labelsize=16)
ax.tick_params(axis='x', labelsize=18)

# Adjust y-axis scale
ax.set_ylim(0, 100)
ax.set_yticks(np.arange(0, 101, 20))

# Add percentage values on top of each bar
def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.1f}%',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=14)

autolabel(male_bars)
autolabel(female_bars)

# Adjust legend to avoid overlap
ax.legend([male_bars, female_bars, national_avg_line], 
          ['Males', 'Females', f'Urban Avg Literacy: {national_avg}%'], 
          loc="best", bbox_to_anchor=(1,1), fontsize=14)

# Adjust layout
fig.tight_layout()

# Save the Urban Literacy Rates image
plt.savefig('Urban_Literacy_Rates.png', dpi=300, bbox_inches='tight')


# Show the plot
plt.show()
