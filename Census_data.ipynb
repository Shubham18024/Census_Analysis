# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
file_path = '/content/drive/MyDrive/india-districts-census-2011.csv'
census_data = pd.read_csv(file_path)
education_level=["Below_Primary_Education", "Primary_Education" , "Middle_Education" , "Secondary_Education" , "Higher_Education" , "Graduate_Education" , "Other_Education"]
total_education = census_data[education_Level].sum()

#To plot a Histogram of total education levels in absolute numbers
plt.figure(figsize=(10, 6))
total_education.plot(kind="bar" , color="black" )
plt.title("Total Education Level Distribution(Absolute Number)")
plt.xlable("Education Level")
plt.ylable("Number of Population")
plt.xticks(rotation=45)
plt.show()

#To plot a Histogram of total education levels in percentage
total_population=census_data[Population].sum()
education_percentage=(total_education/total_population)*100
plt.figure(figsize=(10,6))
education_percentage.plot(kind="bar" , color="skyblue")
plt.title("Total Education Level Distribution(Percentage)")
plt.xlable("Education Level")
plt.ylable("Percentage of Population")
plt.xticks(rotation=45)
plt.show()

#State Education Level Distribution in percentage
state_education = census_data.groupby("State name")[education_level].sum()
state_population = census_data.groupby("State name")['Population'].sum()
state_education_percentage = (state_education.T / state_population).T * 100

state_education_percentage.plot(kind="bar", stacked=True, figsize=(15, 8), colormap="tab20")
plt.title("State-wise Education Level Distribution (Percentage)")
plt.xlabel("State")
plt.ylabel("Percentage")
plt.xticks(rotation=90)
plt.legend(title="Education Level", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

#Scatter plot of Urban/Rural household ratio to Education Level ratio

# Calculate the Urban/Rural Household Ratio
census_data["Urban/Rural Ratio"] = census_data["Urban_Households"] / census_data["Rural_Households"]


long_df = pd.melt(census_data, id_vars=["Urban/Rural Ratio"], value_vars=education_levels, 
                  var_name="Education Level", value_name="Number of Individuals")

# Plot using Seaborn
plt.figure(figsize=(10, 6))
sns.scatterplot(data=long_df, x="Urban/Rural Ratio", y="Number of Individuals", hue="Education Level", s="50", palette=["purple", "blue"] , alpha=0.6)


plt.title("Urban/Rural Household Ratio vs. Education Levels")
plt.xlabel("Urban/Rural Household Ratio")
plt.ylabel("Number of Individuals")

plt.show()
