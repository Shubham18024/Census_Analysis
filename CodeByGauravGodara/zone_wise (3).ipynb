# %% [markdown]
# #  Compare the national average literacy rate with the literacy rate of  Zonal Courcils (2011)
# ## Aim -
# Relation Between the  Zonal Councils literacy rate and national average of literacy rate using graphs.
# ## Formula used -
# Literacy Rate(%)= (Total literates/Population Aged 7 and above)*100
# ## Data Source -
# The Data used for the analysis is sourced from census website (https://censusindia.gov.in/census.website/data/census-tables#).
# ## Refined Data -
# Here is the data source of CSV files used in this analysis [(zones_literacy_file)(https://github.com/Shubham18024/Census_Analysis/blob/main/CSV%20files%20for%201991%2C2001%2C2011/ZONEWISE_EDUCATION_2011.csv)]
#
# ## Zone Divided -
# India is divided into 6 different zones on the basis of (North,south,east,west,central and northeast). The information regarding which state lies in which region can be found here from the official government website [https://www.mha.gov.in/sites/default/files/ZCS-CitiCharter-130710_1.pdf].
# ## Visualisation
# Below is the code written to generate a Bar chat of literacy rates Zonal Coursils along with a comparsion to the national average literacy rate.

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_zone_wise_literacy = pd.read_csv('ZONEWISE_EDUCATION_2011.csv')
df_zone_wise_literacy
df_zone_wise_literacy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 40 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   S.no.                                                                    6 non-null      int64
#  1   ZONAL COUNCILS                                                           6 non-null      object
#  2   Total Population                                                         6 non-null      int64
#  3   Total Population age 7 and above                                         6 non-null      int64
#  4   Total Males                                                              6 non-null      int64
#  5   Total Females                                                            6 non-null      int64
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# The literacy rates of India (2011)
literacy_rate_india_2011 = 72.98

# Load the data from the CSV file
df_zone_wise_literacy = pd.read_csv('ZONEWISE_EDUCATION_2011.csv')

# Set up the matplotlib figure
plt.figure(figsize=(18, 12))

# Create the bar plot
ax = sns.barplot(y='LITERACY RATES (%)', x='ZONAL COUNCILS', color="blue", data=df_zone_wise_literacy)

# Adjust the bar width
bar_width = 0.35
for patch in ax.patches:
    current_width = patch.get_width()
    diff = current_width - bar_width
    # we change the bar width
    patch.set_width(bar_width)
    # we recenter the bar
    patch.set_x(patch.get_x() + diff * .5)

# Add labels and title
plt.ylim(0, 100)
plt.ylabel('Literacy Rates (%)', fontsize=25, fontweight='bold', fontname="Times New Roman")
plt.xticks(rotation=0, fontsize=18, fontweight='bold')
plt.yticks(fontsize=16) 
plt.axhline(y=literacy_rate_india_2011, color='r', linestyle='--', label='National Average')

# Add value labels on top of each bar
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 1, f'{height:.2f}', ha="center", va="bottom", fontsize=14, fontname="Times New Roman")

# Remove x-axis label
plt.xlabel('')

# Add legend
plt.legend(fontsize=14, loc="best", bbox_to_anchor=(1, 1))

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# The literacy rates of India (2011)
literacy_rate_india_2011 = 72.98

# Load the data from the CSV file
df_zone_wise_literacy = pd.read_csv('ZONEWISE_EDUCATION_2011.csv')

# Set up the matplotlib figure
plt.figure(figsize=(18, 12))

# Create the bar plot
ax = sns.barplot(y='LITERACY RATES (%)', x='ZONAL COUNCILS', color="blue", data=df_zone_wise_literacy)

# Adjust the bar width
bar_width = 0.35
for patch in ax.patches:
    current_width = patch.get_width()
    diff = current_width - bar_width
    # we change the bar width
    patch.set_width(bar_width)
    # we recenter the bar
    patch.set_x(patch.get_x() + diff * .5)

# Add labels and title
plt.ylim(0, 100)
plt.ylabel('Literacy Rates (%)', fontsize=25, fontweight='bold', fontname="Times New Roman")
plt.xticks(rotation=0, fontsize=18, fontweight='bold',fontname="Times New Roman")
plt.yticks(fontsize=16) 
plt.axhline(y=literacy_rate_india_2011, color='r', linestyle='--', label='National Average')

# Add value labels on top of each bar
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 1, f'{height:.2f}', ha="center", va="bottom", fontsize=14, fontname="Times New Roman")

# Remove x-axis label
plt.xlabel('')

# Add legend
plt.legend(fontsize=14, loc="best", bbox_to_anchor=(1, 1))

# Adjust layout
plt.tight_layout()

# Save the plot as PDF with 300 DPI
plt.savefig('literacy_rates_india_2011.pdf', dpi=300, format='pdf', bbox_inches='tight')

# Close the plot to free up memory
plt.close()
