# %% [markdown]
# #  Compare the national average literacy rate with the literacy rate of  states and Union territories (1991,2001,2011)
# ## Aim -
# Relation Between the states literacy rate and national average of literacy rate using graphs
# ## Formula used -
# Literacy rate: (Total literates/Population Aged 7 and above)*100
# ## Data Source -
# The Data used for the analysis is sourced from census website (https://censusindia.gov.in/census.website/data/census-tables#).
# ## Refined Data -
# Here is the data source of CSV files used in this analysis[file1_state_1991](https://github.com/Shubham18024/Census_Analysis/blob/main/CSV%20files%20for%201991%2C2001%2C2011/1991-STATE.csv),[file2_ut_1991](https://github.com/Shubham18024/Census_Analysis/blob/main/CSV%20files%20for%201991%2C2001%2C2011/LITERACY1991-UT.csv),[file3_state_2001](https://github.com/Shubham18024/Census_Analysis/blob/main/CSV%20files%20for%201991%2C2001%2C2011/LITERACY2001-STATE.csv),[file4_ut_2001](https://github.com/Shubham18024/Census_Analysis/blob/main/CSV%20files%20for%201991%2C2001%2C2011/LITERACY2001-UT.csv),[file5_state_2011](https://github.com/Shubham18024/Census_Analysis/blob/main/CSV%20files%20for%201991%2C2001%2C2011/LITERACY2011-STATE.csv),[file6_ut_2011](https://github.com/Shubham18024/Census_Analysis/blob/main/CSV%20files%20for%201991%2C2001%2C2011/LITERACY2011-UT.csv)
# ## Visualisation
# Below is the code written to generate a Bar chat of literacy rates states and Union territories along with a comparsion to the national average literacy rate.

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_1991_state = pd.read_csv('LITERACY1991-STATE.csv')
df_1991_state
# Out:
#     S.No.                 States  Total population (Total Population 1991)  \
# 0       1  India (Excluding J&K)         838567936            84,64,21,039
# 1       2        JAMMU & KASHMIR                 0               78,37,051
# 2       3       Himachal Pradesh           5170877               51,70,877
# 3       4                 Punjab          20281969             2,02,81,969
# 4       5            UTTARANCHAL                 0               70,50,634
# 5       6                Haryana          16463648             1,64,63,648
# 6       7              Rajasthan          44005990             4,40,05,990
# 7       8          Uttar Pradesh         139112287            13,20,61,653
# 8       9                  Bihar          86374465             6,45,30,554
# 9      10                 Sikkim            406457                4,06,457
# 10     11      Arunachal Pradesh            864558                8,64,558
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# The literacy rates of India for each year
literacy_rate_india_1991 = 52.21 
literacy_rate_india_2001 = 64.84  
literacy_rate_india_2011 = 72.98

# Load the data from the CSV file
df = pd.read_csv('LITERACY1991-STATE.csv')

# Sort data by literacy rate for better visualization
df = df.sort_values(by ='Literacy Rate 1991 (%)')

# Set up the matplotlib figure
plt.figure(figsize=(12, 8))
sns.barplot(y='Literacy Rate 1991 (%)', x='States', color = "blue" ,data=df )
# Add labels and title
plt.ylabel('Literacy Rate (%) ')
plt.xlabel('States')
plt.title('Literacy Rate of Each States in India (1991)')
plt.xticks(rotation=90)
plt.axhline(y=literacy_rate_india_1991, color='r', linestyle='--', label='India Literacy Rate')
plt.show()

# %%
df_1991_UT = pd.read_csv('LITERACY1991-UT.csv')
df_1991_UT
# Out:
#    S.No.            Union Territories  Total population  \
# 0      1        India (Excluding J&K)         838567936
# 1      1                        Delhi           9420644
# 2      2                Daman And Diu            101586
# 3      3       Dadra And Nagar Haveli            138477
# 4      4                  Lakshadweep             51707
# 5      5                  Pondicherry            807785
# 6      6  Andaman And Nicobar Islands            280661
# 7      7                   Chandigarh            642015
#
#   (Total Population 1991)  Total Population Age 7 and Above  Total Males  \
# 0            84,64,21,039                         688156096    435208158
# 1               94,20,644                           7813248      5155512
# 2                1,01,586                             85808        51595
# 3                1,38,477                            110140        70953
# 4                  51,707                             42243        26618
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# The literacy rates of India for each year
literacy_rate_india_1991 = 52.21 
literacy_rate_india_2001 = 64.84  
literacy_rate_india_2011 = 72.98

# Load the data from the CSV file
df = pd.read_csv('LITERACY1991-UT.csv')

# Sort data by literacy rate for better visualization
df = df.sort_values(by ='Literacy Rate 1991 (%)')

# Set up the matplotlib figure
plt.figure(figsize=(12, 8))
sns.barplot(y='Literacy Rate 1991 (%)', x='Union Territories', color = "blue" ,data=df )
# Add labels and title
plt.ylabel('Literacy Rate (%) ')
plt.xlabel('Union Territories')
plt.title('Literacy Rate of Each UTs in India(1991)')
plt.xticks(rotation=90)
plt.axhline(y=literacy_rate_india_1991, color='r', linestyle='--', label='India Literacy Rate')
plt.show()

# %%
df_2001 = pd.read_csv('LITERACY2001-STATE.csv')

df_2001.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 47 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   S.No.                                                                    29 non-null     int64
#  1   States                                                                   29 non-null     object
#  2   Total Population                                                         29 non-null     int64
#  3   Total Population Age 7 and Above                                         29 non-null     int64
#  4   Total Males                                                              29 non-null     int64
#  5   Total Females                                                            29 non-null     int64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# The literacy rates of India for each year


literacy_rate_india_1991 = 52.21 
literacy_rate_india_2001 = 64.84  
literacy_rate_india_2011 = 72.98

# Load the data from the CSV file
df = pd.read_csv('LITERACY2001-STATE.csv')

# Sort data by literacy rate for better visualization
df = df.sort_values(by ='Literacy Rate (2001) (%)')

# Set up the matplotlib figure
plt.figure(figsize=(12, 8))
sns.barplot(y='Literacy Rate (2001) (%)', x='States', color = "blue" ,data=df )
# Add labels and title
plt.ylabel('Literacy Rate  (%) ')
plt.xlabel('States')
plt.title('Literacy Rate of Each States in India(2001)')
plt.xticks(rotation=90)
plt.axhline(y=literacy_rate_india_2001, color='r', linestyle='--', label='India Literacy Rate')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# The literacy rates of India for each year
literacy_rate_india_1991 = 52.21 
literacy_rate_india_2001 = 64.84  
literacy_rate_india_2011 = 72.98

# Load the data from the CSV file
df = pd.read_csv('LITERACY2001-UT.csv')

# Sort data by literacy rate for better visualization
df = df.sort_values(by ='Literacy Rate (2001) (%)')

# Set up the matplotlib figure
plt.figure(figsize=(12, 8))
sns.barplot(y='Literacy Rate (2001) (%)', x='Union Territories', color = "blue" ,data=df )
# Add labels and title
plt.ylabel('Literacy Rate (%) ')
plt.xlabel('Union Territories')
plt.title('Literacy Rate of Each UTs in India(2001)')
plt.xticks(rotation=90)
plt.axhline(y=literacy_rate_india_2001, color='r', linestyle='--', label='India Literacy Rate')
plt.show()

# %%
df_2011 = pd.read_csv('LITERACY2011-STATE.csv')
df_2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 44 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   S.no.                                                                    29 non-null     int64
#  1   States                                                                   29 non-null     object
#  2   Total Population                                                         29 non-null     int64
#  3   Total Population age 7 and above                                         29 non-null     int64
#  4   Total Males                                                              29 non-null     int64
#  5   Total Females                                                            29 non-null     int64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# The literacy rates of India for each year
literacy_rate_india_1991 = 52.21 
literacy_rate_india_2001 = 64.84  
literacy_rate_india_2011 = 72.98

# Load the data from the CSV file
df = pd.read_csv('LITERACY2011-STATE.csv')

# Sort data by literacy rate for better visualization
df = df.sort_values(by ='Literacy Rate 2011 (%)')

# Set up the matplotlib figure
plt.figure(figsize=(12, 8))
sns.barplot(y='Literacy Rate 2011 (%)', x='States', color = "blue" ,data=df )
# Add labels and title
plt.ylabel('Literacy Rate (%) ')
plt.xlabel('States')
plt.title('Literacy Rate of Each States in India(2011)')
plt.xticks(rotation=90)
plt.axhline(y=literacy_rate_india_2011, color='r', linestyle='--', label='India Literacy Rate')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# The literacy rates of India for each year
literacy_rate_india_1991 = 52.21 
literacy_rate_india_2001 = 64.84  
literacy_rate_india_2011 = 72.98

# Load the data from the CSV file
df = pd.read_csv('LITERACY2011-UT.csv')

# Sort data by literacy rate for better visualization
df = df.sort_values(by ='Literacy Rate 2011 (%)')

# Set up the matplotlib figure
plt.figure(figsize=(12, 8))
sns.barplot(y='Literacy Rate 2011 (%)', x='Union Territories', color = "blue" ,data=df )
# Add labels and title
plt.ylabel('Literacy Rate (%) ')
plt.xlabel('Union Territories')
plt.title('Literacy Rate of Each UTs in India(2011)')
plt.xticks(rotation=90)
plt.axhline(y=literacy_rate_india_2011, color='r', linestyle='--', label='India Literacy Rate')
plt.show()
